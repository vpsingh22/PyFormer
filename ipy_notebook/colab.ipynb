# %%
! git clone https://github.com/vpsingh22/PyFormer.git
# Out:
# Cloning into 'PyFormer'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 82 (delta 43), reused 64 (delta 26), pack-reused 0
# Unpacking objects: 100% (82/82), done.

# %%
% cd PyFormer
# Out:
# /content/PyFormer

# %%
! pip install -r requirements.txt --user
# Out:
# Collecting torchtext==0.4
#   Downloading https://files.pythonhosted.org/packages/43/94/929d6bd236a4fb5c435982a7eb9730b78dcd8659acf328fd2ef9de85f483/torchtext-0.4.0-py3-none-any.whl (53kB)
#      |████████████████████████████████| 61kB 8.6MB/s
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4->-r requirements.txt (line 1)) (1.19.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4->-r requirements.txt (line 1)) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4->-r requirements.txt (line 1)) (2.23.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4->-r requirements.txt (line 1)) (1.8.0+cu101)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from torchtext==0.4->-r requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4->-r requirements.txt (line 1)) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4->-r requirements.txt (line 1)) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4->-r requirements.txt (line 1)) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext==0.4->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->torchtext==0.4->-r requirements.txt (line 1)) (3.7.4.3)
# Installing collected packages: torchtext, colorama
# Successfully installed colorama-0.4.4 torchtext-0.4.0

# %%
! python3 main.py
# Out:
# The model has 9,624,078 trainable parameters
# started training model ..
#
# Epoch: 01 | Time: 0m 15s
# 	Train Loss: 4.079 | Train PPL:  59.063
# 	 Val. Loss: 2.808 |  Val. PPL:  16.576
# Epoch: 02 | Time: 0m 16s
# 	Train Loss: 2.551 | Train PPL:  12.815
# 	 Val. Loss: 2.388 |  Val. PPL:  10.887
# Epoch: 03 | Time: 0m 16s
# 	Train Loss: 2.156 | Train PPL:   8.639
# 	 Val. Loss: 2.144 |  Val. PPL:   8.533
# Epoch: 04 | Time: 0m 16s
# 	Train Loss: 1.877 | Train PPL:   6.537
# 	 Val. Loss: 1.962 |  Val. PPL:   7.111
# Epoch: 05 | Time: 0m 16s
# 	Train Loss: 1.655 | Train PPL:   5.234
# 	 Val. Loss: 1.832 |  Val. PPL:   6.248
# Epoch: 06 | Time: 0m 16s
# 	Train Loss: 1.465 | Train PPL:   4.326
# 	 Val. Loss: 1.743 |  Val. PPL:   5.716
# Epoch: 07 | Time: 0m 16s
# 	Train Loss: 1.304 | Train PPL:   3.685
# 	 Val. Loss: 1.638 |  Val. PPL:   5.144
# Epoch: 08 | Time: 0m 16s
# 	Train Loss: 1.175 | Train PPL:   3.239
# 	 Val. Loss: 1.562 |  Val. PPL:   4.767
# Epoch: 09 | Time: 0m 16s
# 	Train Loss: 1.062 | Train PPL:   2.891
# 	 Val. Loss: 1.539 |  Val. PPL:   4.658
# Epoch: 10 | Time: 0m 16s
# 	Train Loss: 0.956 | Train PPL:   2.601
# 	 Val. Loss: 1.506 |  Val. PPL:   4.511
# Epoch: 11 | Time: 0m 16s
# 	Train Loss: 0.868 | Train PPL:   2.383
# 	 Val. Loss: 1.463 |  Val. PPL:   4.319
# Epoch: 12 | Time: 0m 16s
# 	Train Loss: 0.795 | Train PPL:   2.215
# 	 Val. Loss: 1.443 |  Val. PPL:   4.234
# Epoch: 13 | Time: 0m 16s
# 	Train Loss: 0.730 | Train PPL:   2.075
# 	 Val. Loss: 1.432 |  Val. PPL:   4.186
# Epoch: 14 | Time: 0m 16s
# 	Train Loss: 0.681 | Train PPL:   1.976
# 	 Val. Loss: 1.449 |  Val. PPL:   4.260
# Epoch: 15 | Time: 0m 16s
# 	Train Loss: 0.631 | Train PPL:   1.880
# 	 Val. Loss: 1.416 |  Val. PPL:   4.122
# Epoch: 16 | Time: 0m 16s
# 	Train Loss: 0.593 | Train PPL:   1.810
# 	 Val. Loss: 1.427 |  Val. PPL:   4.166
# Epoch: 17 | Time: 0m 16s
# 	Train Loss: 0.557 | Train PPL:   1.745
# 	 Val. Loss: 1.422 |  Val. PPL:   4.145
# Epoch: 18 | Time: 0m 16s
# 	Train Loss: 0.526 | Train PPL:   1.693
# 	 Val. Loss: 1.435 |  Val. PPL:   4.198
# Epoch: 19 | Time: 0m 16s
# 	Train Loss: 0.498 | Train PPL:   1.645
# 	 Val. Loss: 1.446 |  Val. PPL:   4.246
# Epoch: 20 | Time: 0m 16s
# 	Train Loss: 0.477 | Train PPL:   1.612
# 	 Val. Loss: 1.443 |  Val. PPL:   4.234
# Epoch: 21 | Time: 0m 16s
# 	Train Loss: 0.451 | Train PPL:   1.571
# 	 Val. Loss: 1.448 |  Val. PPL:   4.257
# Epoch: 22 | Time: 0m 16s
# 	Train Loss: 0.434 | Train PPL:   1.544
# 	 Val. Loss: 1.455 |  Val. PPL:   4.286
# Epoch: 23 | Time: 0m 16s
# 	Train Loss: 0.414 | Train PPL:   1.513
# 	 Val. Loss: 1.502 |  Val. PPL:   4.490
# Epoch: 24 | Time: 0m 16s
# 	Train Loss: 0.401 | Train PPL:   1.493
# 	 Val. Loss: 1.499 |  Val. PPL:   4.476
# Epoch: 25 | Time: 0m 16s
# 	Train Loss: 0.388 | Train PPL:   1.474
# 	 Val. Loss: 1.478 |  Val. PPL:   4.386
# Epoch: 26 | Time: 0m 16s
# 	Train Loss: 0.373 | Train PPL:   1.453
# 	 Val. Loss: 1.527 |  Val. PPL:   4.606
# Epoch: 27 | Time: 0m 16s
# 	Train Loss: 0.358 | Train PPL:   1.430
# 	 Val. Loss: 1.477 |  Val. PPL:   4.382
# Epoch: 28 | Time: 0m 16s
# 	Train Loss: 0.346 | Train PPL:   1.414
# 	 Val. Loss: 1.497 |  Val. PPL:   4.469
# Epoch: 29 | Time: 0m 16s
# 	Train Loss: 0.334 | Train PPL:   1.396
# 	 Val. Loss: 1.494 |  Val. PPL:   4.454
# Epoch: 30 | Time: 0m 16s
# 	Train Loss: 0.324 | Train PPL:   1.383
# 	 Val. Loss: 1.506 |  Val. PPL:   4.507
# Epoch: 31 | Time: 0m 16s
# 	Train Loss: 0.313 | Train PPL:   1.367
# 	 Val. Loss: 1.491 |  Val. PPL:   4.444
# Epoch: 32 | Time: 0m 16s
# 	Train Loss: 0.302 | Train PPL:   1.353
# 	 Val. Loss: 1.501 |  Val. PPL:   4.487
# Epoch: 33 | Time: 0m 16s
# 	Train Loss: 0.298 | Train PPL:   1.347
# 	 Val. Loss: 1.529 |  Val. PPL:   4.615
# Epoch: 34 | Time: 0m 16s
# 	Train Loss: 0.287 | Train PPL:   1.333
# 	 Val. Loss: 1.515 |  Val. PPL:   4.548
# Epoch: 35 | Time: 0m 16s
# 	Train Loss: 0.278 | Train PPL:   1.321
# 	 Val. Loss: 1.539 |  Val. PPL:   4.659
# Epoch: 36 | Time: 0m 16s
# 	Train Loss: 0.270 | Train PPL:   1.310
# 	 Val. Loss: 1.569 |  Val. PPL:   4.804
# Epoch: 37 | Time: 0m 16s
# 	Train Loss: 0.264 | Train PPL:   1.302
# 	 Val. Loss: 1.574 |  Val. PPL:   4.826
# Epoch: 38 | Time: 0m 16s
# 	Train Loss: 0.262 | Train PPL:   1.299
# 	 Val. Loss: 1.580 |  Val. PPL:   4.854
# Epoch: 39 | Time: 0m 16s
# 	Train Loss: 0.251 | Train PPL:   1.285
# 	 Val. Loss: 1.577 |  Val. PPL:   4.842
# Epoch: 40 | Time: 0m 16s
# 	Train Loss: 0.247 | Train PPL:   1.280
# 	 Val. Loss: 1.574 |  Val. PPL:   4.826
# Epoch: 41 | Time: 0m 16s
# 	Train Loss: 0.237 | Train PPL:   1.268
# 	 Val. Loss: 1.604 |  Val. PPL:   4.975
# Epoch: 42 | Time: 0m 16s
# 	Train Loss: 0.233 | Train PPL:   1.263
# 	 Val. Loss: 1.639 |  Val. PPL:   5.148
# Epoch: 43 | Time: 0m 16s
# 	Train Loss: 0.226 | Train PPL:   1.253
# 	 Val. Loss: 1.609 |  Val. PPL:   4.996
# Epoch: 44 | Time: 0m 16s
# 	Train Loss: 0.219 | Train PPL:   1.244
# 	 Val. Loss: 1.612 |  Val. PPL:   5.013
# Epoch: 45 | Time: 0m 16s
# 	Train Loss: 0.219 | Train PPL:   1.245
# 	 Val. Loss: 1.626 |  Val. PPL:   5.084
# Epoch: 46 | Time: 0m 15s
# 	Train Loss: 0.211 | Train PPL:   1.235
# 	 Val. Loss: 1.646 |  Val. PPL:   5.187
# Epoch: 47 | Time: 0m 16s
# 	Train Loss: 0.208 | Train PPL:   1.232
# 	 Val. Loss: 1.646 |  Val. PPL:   5.186
# Epoch: 48 | Time: 0m 16s
# 	Train Loss: 0.204 | Train PPL:   1.226
# 	 Val. Loss: 1.636 |  Val. PPL:   5.137
# Epoch: 49 | Time: 0m 16s
# 	Train Loss: 0.203 | Train PPL:   1.225
# 	 Val. Loss: 1.630 |  Val. PPL:   5.104
# Epoch: 50 | Time: 0m 16s
# 	Train Loss: 0.195 | Train PPL:   1.216
# 	 Val. Loss: 1.675 |  Val. PPL:   5.336

# %%
! git pull https://github.com/vpsingh22/PyFormer.git
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/vpsingh22/PyFormer
#  * branch            HEAD       -> FETCH_HEAD
# Updating 558c174..fe5c888
# Fast-forward
#  config.py   |  5 +++--
#  pyformer.py | 28 ++++++++++++++++++++++++++++
#  2 files changed, 31 insertions(+), 2 deletions(-)

# %%
! python3 pyformer.py
# Out:
# write a program to add two numbers
#
#
#
# num1 = 1.5
# num2 = 6.3
# sum = num1 + num2
# print ( f 'Sum: {sum}' )
#
#
#
#
# Write a python function to merge two given lists into one
#
#
# def merge_lists ( l1, l2 ) :
# 	return l1 + l2
#
#
#
#
# Write a program to print the multiplication table of a given number
#
#
#
# num = 9
# for i in range ( 1, 11 ) :
# 	print ( num, 'x', i, '=', num * i )
#
#
#
#
# Write a python function to find the area of a circle, whose radius is given
#
#
# def findArea ( r ) :
# 	PI = 3.142
# 	return PI * ( r * r )
#
#
#
#
# Write a function that returns the sum of digits of a given number
#
#
# def digisum ( num ) :
# 	sum_ = 0
# 	while num > 0 :
# 		dig = num % 10
# 		sum_ += dig
# 		num //= 10
# 	return sum_
#
#
#
#
# Write a program to calculate and print the volume of a cylinder
#
#
# pi = 22 / 7
# def volume ( r, h ) :
# 	vol = pi * r * r * h
# 	return vol
#
# r = 5
# h = 8
#
# print ( "Volume Of Cylinder = ", volume ( r, h ) )
#
#
#
#
# Write a function to calculate compound interest, given p, r, t
#
#
# def comp_int ( p, r, t ) :
# 	amount = p * ( 1 + ( r / 100 ) ** t
# 	interest = amount - p
# 	return interest
#
#
#
#
# Write a program that prints all the alphabets in a string and skips all other characters
#
#
#
# string = "$john.snow#@Got.bad_ending/com"
# for ch in string :
# 	if ( ch >= 'A' and ch<='Z') or (ch>='a' and ch<='z' ) :
# 		print ( ch, end = '' )
# 	else :
# 		pass
#
#
#
#
# write a Python program to get the largest number from a list
#
#
# def max_num_in_list ( list ) :
# 	max = list [ 0 ]
# 	for a in list :
# 		max = a if a > max else max
# print ( f 'max_num_in_list [1, 10, -8, 0], Ans:{max_num_in_list([1, 10, -8, 0])}' )
#
#
#
#
# write a python program to check name exists in given list
#
#
# names1 = [ 'Amir', 'Bala', 'Chales' ]
# for n in names1 :
# 	name = n.lower ( )
# 	if 'amir' == name :
# 		print ( 'Yes name exists:', name )
# 	else :
# 		print ( 'No' )
#
#
#
#
# write a python to check two numbers are greater than or equal or less than
#
#
# def maximum ( x, y ) :
# 	if x > y :
# 		return x
# 	elif x == y :
# 		return 'The numbers are equal'
# 	else :
# 		return y
#
# print ( maximum ( 2, 3 ) )
#
#
#
#
# python program to find power of number using recursion
#
#
# def power ( N, P ) :
# 	if ( P == 0 or P == 1 ) :
# 		return N
# 	else :
# 		return ( N * power ( N, P - 1 ) )
#
# print ( power ( 5, 2 ) )
#
#
#
#
# Python program to find the  difference between two times
#
#
# def difference ( h1, m1, h2, m2 ) :
#
# 	t1 = h1 * 60 + m1
# 	t2 = h2 * 60 + m2
# 	if ( t1 == t2 ) :
# 		print ( "Both are same times" )
# 		return
# 	else :
# 		diff = t2 - t1
# 	h = ( int ( diff / 60 ) ) % 24
# 	m = diff % 60
# 	print ( h, ":", m )
# difference ( 7, 20, 9, 45 )
# difference ( 15, 23, 23, 54 )
# difference ( 16, 20, 20, 20 )
#
#
#
#
# Python program to find time for a given angle.
#
#
#
# def calcAngle ( hh, mm ) :
#
# 	hour_angle = 0.5 * ( hh * 60 + mm )
# 	minute_angle = 6 * mm
#
# 	angle = abs ( hour_angle - minute_angle )
# 	angle = min ( 360 - angle, angle )
# 	return angle
#
# def printTime ( theta ) :
#
#
# 	for hh in range ( 0, 12 ) :
# 		for mm in range ( 0, 60 ) :
# 			if ( calcAngle ( hh, mm ) == theta ) :
# 				print ( hh, ":", mm, sep = "" )
# 					return
#
#
# 	print ( "Input angle not valid." )
# 	return
# theta = 90.0
# printTime ( theta )
#
#
#
#
# Write a function to get list of profanity words from Google profanity URL
#
#
# def profanitytextfile ( ) :
# 	url = "https://github.com/RobertJGabriel/Google-profanity-words/blob/master/list.txt"
# 	html = urlopen ( url ).read ( )
# 	soup = BeautifulSoup ( html, features = "html.parser" )
#
# 	textlist = [ ]
# 	table = soup.find ( 'table' )
# 	trs = table.find_all ( 'tr' )
# 	for tr in trs :
# 		tds = tr.find_all ( 'td' )
# 		for td in tds :
# 			textlist.append ( td.text )
# 	return textlist
#
#
#
#
# write a program to accept a string if it contains all vowels
#
#
#
# str1 = "what a great day!"
# print ( "".join ( set ( str1 ) ) )
#
#
#
#
# write a program to rotate string left and right by d length
#
#
#
# def rotate ( input, d ) :
#
# 	Lfirst = input [ 0 : d ]
# 	Lsecond = input [ d : ]
# 	Rfirst = input [ 0 : len ( input ) - d ]
# 	Rsecond = input [ len ( input ) - d : ]
#
#
# 	print ( "Left Rotation : ", ( Lsecond + Lfirst ) )
# 	print ( "Right Rotation : ", ( Rsecond + Rfirst ) )
# input = 'GeeksforGeeks'
# d = 2
# rotate ( input, d )
#
#
#
#
# write a program to remove the duplicate words
#
#
# def remove_duplicate_words ( string ) :
# 	string = string.strip ( ).split ( )
# 	return ' '.join ( set ( string ) )
#
#
#
#
#
# write program to extract digits from Tuple list
#
#
# test_list = [ ( 1, 3, 4 ), ( 5, 6, 9 ), ( 7, 10 ), ( 99, 2 ) ]
#
# print ( "The original list is : " + str ( test_list ) )
#
# res = [ ]
# for sub in test_list :
# 	for ele in sub :
# 		res.setdefault ( ele ).append ( ele )
# print ( "The extrated digits : " + str ( res ) )
#
#
#
#
# write a program to convert time from 12 hour to 24 hour format
#
#
# def convert24 ( str1 ) :
# 	if str1 [ - 2 : ] == "AM" and str1[:2] == "12" :
# 		return "00" + str1 [ 2 : - 2 ]
# 	elif str1 [ - 2 : ] == "AM" :
# 		return str1 [ : - 2 ]
#
# 	elif str1 [ - 2 : ] == "PM" and str1[:2] == "12" :
# 		return str1 [ : - 2 ]
#
#
# print ( convert24 ( str1 [ : 2 ] ) )
#
#
#
#
# write a program to delete all duplicate letters in a string
#
#
#
# str1 = "what a great day!"
# print ( "".join ( set ( str1 ) ) )
#
#
#
#
# write a program to print Maximum frequency character in String
#
#
#
# str1 = "watch the match"
# all_freq = { }
# for i in str1 :
# 	if i in all_freq :
# 		all_freq [ i ] += 1
# 	else :
# 		all_freq [ i ] = 1
# res = max ( all_freq, key = all_freq.get )
# print ( "Maximum of all characters is: " + str ( res ) )
#
#
#
#
# write a program to check if a string is binary or not
#
#
#
# str1 = "01110011 a"
#
# set1 = set ( str1 )
#
# if set1 == { '0','1'} or set1 == {'0'} or set1 == {'1' } :
# 	print ( "string is binary" )
# else :
# 	print ( "string is not binary" )
#
#
#
#
# write a program to check whether a given string is Heterogram or not
#
#
# def heterogram ( input ) :
#
# 	alphabets = [ ch for ch in input if ( ord ( ch ) >= ord ( 'a') and ord(ch) <= ord('z' ) ) ]
#
# 	if len ( set ( alphabets ) ) :
# 		print ( 'Yes' )
# 	else :
# 		print ( 'No' )
#
# if __name__ == "__main__" :
# 	input = 'Hello World'
# 	heterogram ( input )
#
#
#
#
# write a program to check whether a given key already exists in a dictionary
#
#
#
# def checkKey ( dict, key ) :
#
# 	if key in dict.keys ( ) :
# 		print ( "Present, ", end =" " )
# 		print ( "value =", dict [ key ] )
# 	else :
# 		print ( "Not present" )
#
# dict = { 'a': 100, 'b':200, 'c' : 300 }
#
# key = 'b'
# checkKey ( dict, key )
#
# key = 'w'
# checkKey ( dict, key )
#
#
#
#
# write a program to reverse words of string
#
#
# def find_longest_word ( words_list ) :
# 	word_len = [ ]
# 	for n in words_list :
# 		word_len.append ( ( ( len ( n ), n ) ) )
# 		word_len.sort ( )
# 	return word_len [ - 1 ] [ 1 ] [ 1 ], word_len [ 1 ] [ 1 ] [ 1 ] )
# print ( find_longest_word ( [ "PHP", "python", "zekelabs" ] ) )
#
#
#
#
# write a program to remove i-th indexed character from a string
#
#
#
# str1 = "IISC is the best. IISC has Classes in the evening for professionals. Classes help to learn new things."
#
# repl_dict = { 'IISC':'It', 'Classes': 'They' }
#
# str_list = str1.split ( ' ' )
#
# res = set ( )
#
# for idx, ele in enumerate ( str_list ) :
# 	if ele in repl_dict :
# 		print ( str ( idx ) + ele )
# 		if ele in res :
# 		print ( idx )
# 		else :
# 			res.add ( ele )
#
# res = ' '.join ( str_list )
#
# print ( "Replaced String: " + str ( res ) )
#
#
#
#
# write a program extract least frequency element
#
#
#
# from collections import defaultdict
# test_list = [ 1, 3, 4, 5, 6 ]
#
# print ( "The original list : " + str ( test_list ) )
#
# res = defaultdict ( int )
# for ele in test_list :
# 	res [ ele ] += 1
# min_occ = 9999
# for ele in res :
# 	if min_occ > res :
# 		min_occ = res [ ele ]
# 			tar_ele = ele
#
# print ( "The minimum occurring element is : " + str ( tar_ele ) )
#
#
#
#
# write a program to check 2 lists and find if any element is common
#
#
#
# def common_data ( list1, list2 ) :
# 	result = False
# 	for x in list1 :
# 		for y in list2 :
# 			if x == y :
# 				result = True
# 						break
# 	return result
#
# a = [ 1, 2, 3, 4, 5 ]
# b = [ 6, 7, 8, 9 ]
# print ( common_data ( a, b ) )
#
#
#
#
# write a program to check if the year is a leap year
#
#
#
# year = int ( input ( "Enter a year: " ) )
# if ( year % 4 ) == 0 :
# 	if ( year % 100 ) == 0 :
# 		if ( year % 400 ) == 0 :
# 			print ( f "{year} is a leap year" )
# 		else :
# 			print ( f "{year} is not a leap year" )
# 	else :
# 		print ( f "{year} is a leap year" )
# else :
# 	print ( f "{year} is not a leap year" )
#
#
#
#
# write a program to check if the number is a prime numnber
#
#
# num = int ( input ( "Enter a number: " ) )
#
# if num > 1 :
# 	for i in range ( 2, num ) :
# 		if ( num % i ) == 0 :
# 			print ( num, "is not a prime number" )
# 			print ( i, "times",num//i,"is", num )
# 			break
# 	else :
# 			print ( num, "is a prime number" )
#
# else :
# 	print ( num, "is not a prime number" )
#
#
#
#
# write a program to check Armstrong number
#
#
#
# num = int ( input ( "Enter a number: " ) )
#
# sum = 0
#
# temp = num
# while temp > 0 :
# 	digit = temp % 10
# 	sum += digit ** 3
# 	temp //= 10
#
# if num == sum :
# 	print ( num, "is an Armstrong number" )
# else :
# 	print ( num, "is not an Armstrong number" )
#
#
#
#
# write a  program to find HCF
#
#
#
# x = int ( input ( "Enter the value of x :" ) )
# y = int ( input ( "Enter the value of y :" ) )
#
# ( x, y, z ) = ( x ) // 2 ) // 10 ) // ( x, x )
# print ( 'Value of x: ', x, '\nValue of y: ', y, '\nWOO!! Values SWAPPEDDD' )
#
#
#
#
# write a  program to sort words in alphabetic order
#
#
#
# my_str = input ( "Enter a string: " )
# words = my_str.split ( )
# words.sort ( )
# for word in words :
# 	print ( word )
#
#
#
#
#
# write a program to remove punctuation from a string
#
#
#
# from string import punctuation
#
# str1 = '/*Jon is @developer & musician!!'
# replace_char = '#'
# for char in punctuation :
# 	str1 = str1.replace ( char, replace_char )
#
# print ( "The strings after replacement : ", str1 )
#
#
#
#
# write a program to display the powers of 2 using anonymous function
#
#
#
# terms = 10
#
# terms = int ( input ( "How many terms? " ) )
#
# result = list ( map ( lambda x : 2 ** x, range ( terms ) ) )
#
# for i in range ( terms ) : 2 * terms ) :
# 	print ( "2 raised to power",i,"is", result [ i ] )
#
#
#
#
# write a program to return the absolute value in Python
#
#
# num = 10
# print ( f 'Absolute of {num} is {abs(num)}' )
#
#
#
#
# write a program to design a dice throw function
#
#
#
# import random
#
# def dice ( ) :
# 	return random.choice ( [ 1, 2, 3, 4, 5, 6 ] )
#
#
#
#
#
# write a program to find variance of a dataset
#
#
#
# def variance ( X ) :
# 	mean = sum ( X ) / len ( X )
# 	tot = 0.0
# 	for x in X :
# 		tot = tot + ( x - mean ) ** 2
# 	return tot / len ( X )
#
# sample = [ 1, 2, 3, 4, 5 ]
#
# print ( "variance of the sample is: ", variance ( sample ) )
#
#
#
#
# Write a python program to Implement Binary Search without Recursion and print the key element if found
#
#
#
# def binary_search ( alist, key ) :
#
# 	start = 0
# 	end = len ( alist )
# 	while start < end :
# 		mid = ( start + end ) // 2
# 		if alist [ mid ] < key :
# 			end = mid
# 		elif alist [ mid ] > key :
# 			start = mid + 1
# 		else :
# 			return mid
#
#
# 		else :
# 			return - 1
#
#
# alist = [ 2, 3, 5, 6, 4, 5 ]
#
#
# key = 6
# if __name__ < 0 :
# 	print ( f '{key} was not found.' )
# else :
# 	print ( f '{key} was found at index {index}.' )

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
def display_attention(sentence, translation, attention, n_heads = 8, n_rows = 4, n_cols = 2):
    
    assert n_rows * n_cols == n_heads
    
    fig = plt.figure(figsize=(15,25))
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                           rotation=45)
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()

# %%
with open()
